# %% [markdown]
# # 🧩 Mini Proyecto 1 – Fundamentos (Integrador)
#
# ---
#
# ## 🎯 Objetivo
#
# Construir un mini programa en Python que:
#
# - Pida datos al usuario (input)
# - Use variables y tipos
# - Use condicionales
# - Use bucles
# - Muestre resultados claros por pantalla
#
# Este mini-proyecto está pensado para que el alumno practique **lo esencial** con un caso realista.

# %% [markdown]
# ## 🧠 Contexto
#
# Vas a construir un **gestor de presupuesto simple**.
#
# El usuario irá metiendo gastos y el programa:
#
# - sumará el total
# - avisará si se supera un límite
# - mostrará resumen final

# %% [markdown]
# ## ✅ Requisitos
#
# Tu programa debe:
#
# 1. Pedir al usuario un **límite de presupuesto** (float).
# 2. Pedir gastos uno a uno hasta que el usuario escriba `fin`.
# 3. Cada gasto debe ser positivo.
# 4. Si el usuario introduce algo no numérico (y no es `fin`), mostrar error y continuar.
# 5. Al final:
#    - mostrar total
#    - mostrar cuánto queda (o cuánto se ha excedido)
#    - indicar si se ha pasado del límite

# %% [markdown]
# ## 🧠 Pistas (casi solución)
#
# - Usa `input()` para leer texto.
# - Convierte con `float()` dentro de un `try/except`.
# - Usa un `while True:` para iterar.
# - Si `texto.lower() == "fin"`: rompe el bucle.
# - Acumula total en una variable `total = 0.0`.
# - Para comprobar si se supera:
#   - `if total > limite:`

# %% [markdown]
# ## 🧪 Ejemplo de ejecución esperada
#
# ```
# Límite: 100
# Gasto (o 'fin'): 20
# Gasto (o 'fin'): 50
# Gasto (o 'fin'): 40
# ⚠️ Has superado el límite
# Gasto (o 'fin'): fin
#
# Total: 110
# Exceso: 10
# Estado: SUPERADO
# ```

# %% [markdown]
# ---
# ## 🧠 Implementación (alumno)
#
# Implementa aquí el programa completo.

# %%
# Tu implementación aquí

# %% [markdown]
# ---
# ## ✅ Checklist
#
# - [ ] Pide límite
# - [ ] Bucle de gastos hasta 'fin'
# - [ ] Validación de número
# - [ ] Validación de positivo
# - [ ] Mensaje si supera límite
# - [ ] Resumen final

# %% [markdown]
# ---
# ## 🔎 Solución
#
# <details>
# <summary>Ver solución</summary>
#
# ```python
# limite = float(input("Límite: "))
# total = 0.0
#
# while True:
#     texto = input("Gasto (o 'fin'): ").strip()
#
#     if texto.lower() == "fin":
#         break
#
#     try:
#         gasto = float(texto)
#     except ValueError:
#         print("❌ Entrada inválida. Escribe un número o 'fin'.")
#         continue
#
#     if gasto <= 0:
#         print("❌ El gasto debe ser positivo")
#         continue
#
#     total += gasto
#
#     if total > limite:
#         print("⚠️ Has superado el límite")
#
# print("\nTotal:", total)
#
# if total > limite:
#     print("Exceso:", total - limite)
#     print("Estado: SUPERADO")
# else:
#     print("Restante:", limite - total)
#     print("Estado: OK")
# ```
#
# </details>
