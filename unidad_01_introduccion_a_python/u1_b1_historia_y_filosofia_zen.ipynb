# %% [markdown]
# # 🐍 Unidad 1 – Introducción a Python
# ## Bloque 1 – Historia y Filosofía (El Zen de Python)
#
# ---
#
# ## 🎯 Objetivos
#
# - Conocer el origen de Python.
# - Entender su filosofía.
# - Leer y analizar el Zen de Python.
# - Reflexionar sobre buenas prácticas.

# %% [markdown]
# ## 📜 Historia breve
#
# - Creado por Guido van Rossum (1989).
# - Enfocado en simplicidad y legibilidad.
# - Multiplataforma y multiparadigma.

# %% [markdown]
# ## 🧘 El Zen de Python
#
# Ejecuta lo siguiente:

# %%
import this

# %% [markdown]
# ## 🧠 Reflexión
#
# Frases clave:
#
# - Beautiful is better than ugly
# - Simple is better than complex
# - Readability counts

# %% [markdown]
# ## 🧠 Ejercicio 1
#
# Escribe en una celda markdown:
#
# ¿Qué significa para ti "Readability counts"?

# %% [markdown]
# ✍️ Tu respuesta aquí:

# %% [markdown]
# ## 🧠 Ejercicio 2
#
# Escribe dos ejemplos de código:
#
# - Uno poco legible
# - Uno más legible

# %%
# Código poco legible

# %%
# Código más legible

# %% [markdown]
# ---
# ## 🏆 Reto Final
#
# Reescribe este código siguiendo el Zen:
#
# ```python
# a=1;b=2;c=a+b;print(c)
# ```
#
# ### ✅ Pistas
#
# - Espacios
# - Nombres claros
# - Legibilidad > compactación

# %%
# Tu solución aquí:
