# %% [markdown]
# # 🐍 Unidad 1 – Introducción a Python
# ## Bloque 2 – Instalación, pip y configuración del IDE
#
# ---
#
# ## 🎯 Objetivos
#
# - Verificar instalación de Python 3.x.
# - Entender qué es pip.
# - Instalar paquetes.
# - Configurar entorno en VS Code.

# %% [markdown]
# ## 🔎 Verificar instalación
#
# Ejecuta en terminal (NO en notebook):
#
# ```bash
# python --version
# ```
#
# Debe mostrar Python 3.x

# %% [markdown]
# ## 📦 ¿Qué es pip?
#
# - Es el gestor de paquetes de Python.
# - Permite instalar librerías externas.

# %% [markdown]
# ## 🛠 Instalar un paquete
#
# En terminal:
#
# ```bash
# pip install requests
# ```

# %% [markdown]
# ## 🧪 Probar paquete instalado

# %%
import requests
print("requests está instalado correctamente")

# %% [markdown]
# ## 🧰 VS Code configuración mínima
#
# - Instalar extensión Python.
# - Seleccionar intérprete.
# - Activar entorno virtual.

# %% [markdown]
# ## 🧠 Ejercicio 1
#
# 1. Crea entorno virtual `.venv`.
# 2. Actívalo.
# 3. Instala paquete `numpy`.
#
# ### ✅ Pistas
#
# - python -m venv .venv
# - source .venv/bin/activate
# - pip install numpy

# %% [markdown]
# ## 🧠 Ejercicio 2
#
# Verifica que numpy está instalado ejecutando:

# %%
import numpy as np
print(np.array([1,2,3]))

# %% [markdown]
# ---
# ## 🏆 Reto Final
#
# 1. Crea entorno nuevo.
# 2. Instala requests y pandas.
# 3. Genera requirements.txt.
# 4. Elimina entorno.
# 5. Créalo de nuevo usando requirements.txt.
#
# ### ✅ Pistas
#
# - pip freeze > requirements.txt
# - pip install -r requirements.txt
