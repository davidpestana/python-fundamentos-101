# %% [markdown]
# # 🐍 Unidad 1 – Introducción a Python
# ## Bloque 3 – Intérprete (REPL) y ejecución de scripts
#
# ---
#
# ## 🎯 Objetivos
#
# - Entender qué es el REPL.
# - Diferenciar entre REPL y script.
# - Ejecutar un archivo .py desde terminal.
# - Escribir el primer programa completo.

# %% [markdown]
# ## 🧠 REPL (Read–Eval–Print Loop)
#
# El REPL permite ejecutar código línea a línea.
#
# En terminal:
#
# ```bash
# python
# ```
#
# En Jupyter cada celda actúa como un mini REPL.

# %%
2 + 10

# %% [markdown]
# ## 📄 Script (.py)
#
# Un script es un archivo con extensión `.py`.
#
# Se ejecuta desde terminal:
#
# ```bash
# python archivo.py
# ```
#
# ⚠️ En esta fase NO generaremos el archivo automáticamente.
#
# 👉 Debes crearlo tú manualmente desde el explorador de VS Code.

# %% [markdown]
# ## 🧠 Ejercicio 1 — Hola Mundo como script
#
# 1. Crea un archivo llamado `hola.py`.
# 2. Escribe dentro:
#
# ```python
# print("Hola Mundo")
# ```
#
# 3. Guarda el archivo.
# 4. En la terminal ejecuta:
#
# ```bash
# python hola.py
# ```
#
# ### ✅ Pistas
#
# - El archivo debe estar en el mismo directorio donde ejecutas el comando.
# - Si da error, revisa que el nombre sea exactamente `hola.py`.

# %% [markdown]
# ## 🧠 Ejercicio 2 — Script con input()
#
# Crea un archivo llamado `saludo.py` que:
#
# 1. Pida el nombre con `input()`.
# 2. Imprima `Hola <nombre>`.
#
# ### ✅ Pistas casi solución
#
# ```python
# nombre = input("Nombre: ")
# print("Hola", nombre)
# ```
#
# Ejecuta luego:
#
# ```bash
# python saludo.py
# ```

# %% [markdown]
# ---
# ## 🏆 Reto Final — mini_programa.py
#
# Crea un archivo `mini_programa.py` que:
#
# 1. Pida nombre.
# 2. Pida edad.
# 3. Imprima: `Hola <nombre>, tienes <edad> años.`
#
# ### ✅ Pistas
#
# - Usa dos variables.
# - Usa `print()` con comas para simplificar.
# - No necesitas convertir la edad todavía.

# %% [markdown]
# ---
# ## 🔎 Solución
#
# <details>
# <summary>Ver solución</summary>
#
# ```python
# nombre = input("Nombre: ")
# edad = input("Edad: ")
# print("Hola", nombre + ", tienes", edad, "años.")
# ```
#
# </details>
