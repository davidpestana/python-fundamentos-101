# %% [markdown]
# # 🐍 Unidad 1 – Introducción a Python
# ## Bloque 5 – Primer Script: input() y print()
#
# ---
#
# ## 🎯 Objetivos
#
# - Entender cómo funciona `input()`.
# - Entender que `input()` siempre devuelve `str`.
# - Usar `print()` para mostrar información.
# - Hacer un mini-programa interactivo de principio a fin.

# %% [markdown]
# ## 🖨️ print(): salida por pantalla
#
# La función `print()` muestra información.
#
# Ejemplos:

# %%
print("Hola")
print("Hola", "Python")
print("Suma:", 2 + 3)

# %% [markdown]
# ## ⌨️ input(): entrada por teclado
#
# `input()` pide un valor al usuario y lo devuelve como texto (`str`).
#
# Ejemplo:

# %%
nombre = input("Nombre: ")
print("Hola", nombre)

# %% [markdown]
# ## ⚠️ input() siempre devuelve texto
#
# Aunque escribas un número, el resultado es `str`.
#
# Ejecuta:

# %%
edad_texto = input("Edad: ")
type(edad_texto)

# %% [markdown]
# Si necesitas operar con números, conviertes el texto.
#
# Ejemplo con `int()`:

# %%
edad = int(input("Edad (número): "))
print("El año que viene tendrás", edad + 1)

# %% [markdown]
# ## 🧠 Ejercicio 1 — Saludo completo
#
# Pide al usuario:
#
# - Nombre
# - Ciudad
#
# E imprime una frase:
#
# - `Hola <nombre>, veo que estás en <ciudad>.`
#
# ### ✅ Pistas (muy guiado)
#
# - Usa 2 variables: `nombre` y `ciudad`.
# - Usa 2 `input(...)`.
# - Usa un solo `print()` para la frase final.
# - Con `print()` puedes separar por comas.

# %%
# Estructura sugerida:
# nombre = input("Nombre: ")
# ciudad = input("Ciudad: ")
# print("Hola", nombre + ", veo que estás en", ciudad + ".")

# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 2 — Suma de dos números
#
# Pide dos números al usuario y muestra la suma.
#
# Ejemplo:
#
# - Entrada: 3 y 5
# - Salida: `La suma es 8`
#
# ### ✅ Pistas (casi solución)
#
# - `input()` devuelve texto, así que convierte con `int()`.
# - Guarda cada número en una variable.
# - Calcula `suma = a + b`.
# - `print("La suma es", suma)`.

# %%
# Estructura sugerida:
# a = int(input("Número 1: "))
# b = int(input("Número 2: "))
# suma = a + b
# print("La suma es", suma)

# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 3 — Calculadora de IVA
#
# Pide un precio (con decimales) y muestra el precio final con IVA (21%).
#
# ### ✅ Pistas (muy guiado)
#
# - Usa `float(input(...))`.
# - Constante: `IVA = 0.21`.
# - Fórmula: `precio_con_iva = precio + (precio * IVA)`.
# - Imprime con `print()`.

# %%
# Estructura sugerida:
# IVA = 0.21
# precio = float(input("Precio: "))
# precio_con_iva = precio + (precio * IVA)
# print("Total:", precio_con_iva)

# Tu solución aquí:

# %% [markdown]
# ---
# ## 🏆 Reto Final — mini_formulario.py (manual)
#
# Crea manualmente (desde VS Code) un archivo `mini_formulario.py` que:
#
# 1. Pida nombre.
# 2. Pida edad (número).
# 3. Pida ciudad.
# 4. Imprima una frase final en una sola línea.
#
# Ejemplo:
#
# - `Hola David (21), vives en Valencia.`
#
# ### ✅ Pistas (casi solución)
#
# - `edad = int(input("Edad: "))`
# - La frase final se construye con `print()` usando comas o concatenación.
# - Recuerda ejecutar desde terminal: `python mini_formulario.py`.

# %% [markdown]
# ---
# ## 🔎 Solución
#
# <details>
# <summary>Ver solución</summary>
#
# ```python
# nombre = input("Nombre: ")
# edad = int(input("Edad: "))
# ciudad = input("Ciudad: ")
#
# print("Hola", nombre, "(" + str(edad) + "), vives en", ciudad + ".")
# ```
#
# </details>
