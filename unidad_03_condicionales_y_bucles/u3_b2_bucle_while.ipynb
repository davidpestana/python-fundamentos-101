# %% [markdown]
# # 🐍 Unidad 3 – Condicionales y Bucles
# ## Bloque 2 – Bucle while
#
# ---
#
# ## 🎯 Objetivos
#
# - Comprender cómo funciona el bucle `while`.
# - Usar condiciones de parada.
# - Evitar bucles infinitos.
# - Aplicar contadores.

# %% [markdown]
# ## 🧠 Estructura básica
#
# ```python
# while condición:
#     bloque
# ```
#
# El bloque se ejecuta mientras la condición sea `True`.

# %%
contador = 0

while contador < 5:
    print("Contador:", contador)
    contador += 1

# %% [markdown]
# ## ⚠️ Bucles infinitos
#
# Si no modificas la condición, el bucle nunca termina.
#
# Ejemplo peligroso (NO ejecutar):
#
# ```python
# while True:
#     print("Nunca termina")
# ```

# %% [markdown]
# ## 🧠 Ejercicio 1 — Cuenta hasta 10
#
# Crea un bucle que imprima números del 1 al 10.
#
# ### ✅ Pistas
#
# - Empieza en 1
# - Condición: `<= 10`
# - Incrementa con `+= 1`

# %%
# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 2 — Suma acumulada
#
# Suma números del 1 al 5 usando `while`.
#
# Resultado esperado: 15
#
# ### ✅ Pistas
#
# - Usa una variable `suma = 0`
# - Acumula con `suma += contador`

# %%
# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 3 — Validación de entrada
#
# Pide al usuario un número hasta que introduzca un valor mayor que 0.
#
# ### ✅ Pistas
#
# - Usa `while numero <= 0`
# - Pide el número dentro del bucle

# %%
# Tu solución aquí:

# %% [markdown]
# ---
# ## 🏆 Reto Final — Adivina el número
#
# 1. Define un número secreto (ej: 7).
# 2. Pide al usuario que adivine.
# 3. Mientras no acierte, sigue preguntando.
# 4. Cuando acierte, muestra "Correcto".
#
# ### ✅ Pistas
#
# - Usa `while intento != secreto`
# - Convierte con `int()`
# - Pide el intento dentro del bucle

# %%
# Tu reto aquí:

# %% [markdown]
# ---
# ## 🔎 Solución
#
# <details>
# <summary>Ver solución</summary>
#
# ```python
# secreto = 7
# intento = int(input("Adivina el número: "))
#
# while intento != secreto:
#     intento = int(input("Intenta de nuevo: "))
#
# print("Correcto")
# ```
#
# </details>
