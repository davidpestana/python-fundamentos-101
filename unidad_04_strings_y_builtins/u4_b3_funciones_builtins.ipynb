# %% [markdown]
# # 🐍 Unidad 4 – Cadenas de Texto y Funciones Predefinidas
# ## Bloque 3 – Funciones predefinidas (built-ins)
#
# ---
#
# ## 🎯 Objetivos
#
# - Conocer funciones built-in esenciales.
# - Usar `len`, `abs`, `round`, `max`, `min`.
# - Entender `sorted` y `reversed`.
# - Aplicarlas en pequeños problemas prácticos.

# %% [markdown]
# ## 📏 len()
#
# Devuelve la longitud de una secuencia.

# %%
print(len("Python"))
print(len([1, 2, 3]))

# %% [markdown]
# ## ➖ abs()
#
# Devuelve el valor absoluto.

# %%
print(abs(-10))

# %% [markdown]
# ## 🔢 round()
#
# Redondea un número.

# %%
print(round(3.1416, 2))

# %% [markdown]
# ## 🔝 max() y min()

# %%
numeros = [3, 7, 2, 9]
print(max(numeros))
print(min(numeros))

# %% [markdown]
# ## 📚 sorted()
#
# Devuelve una nueva lista ordenada.

# %%
numeros = [5, 1, 4]
print(sorted(numeros))
print(numeros)  # original no cambia

# %% [markdown]
# ## 🔄 reversed()
#
# Devuelve un iterador invertido.

# %%
numeros = [1, 2, 3]
print(list(reversed(numeros)))

# %% [markdown]
# ## 🧠 Ejercicio 1 — Analizador numérico
#
# Dada una lista de números:
#
# - Muestra máximo
# - Muestra mínimo
# - Muestra longitud
#
# ### ✅ Pistas
#
# - Usa `max`, `min`, `len`

# %%
# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 2 — Redondeo práctico
#
# Pide un número decimal y muestra:
#
# - Redondeado a 1 decimal
# - Redondeado a 2 decimales
#
# ### ✅ Pista
#
# - `round(numero, 1)`
# - `round(numero, 2)`

# %%
# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 3 — Ordenación
#
# Crea una lista de 5 números y:
#
# - Muéstrala ordenada ascendente
# - Muéstrala ordenada descendente
#
# ### ✅ Pistas
#
# - `sorted(lista)`
# - `sorted(lista, reverse=True)`

# %%
# Tu solución aquí:

# %% [markdown]
# ---
# ## 🏆 Reto Final — Estadísticas rápidas
#
# Pide al usuario 3 números (uno por uno) y:
#
# - Muestra la suma
# - Muestra el máximo
# - Muestra el mínimo
# - Muestra el promedio (redondeado a 2 decimales)
#
# ### ✅ Pistas
#
# - Guarda en una lista
# - Promedio = suma / len(lista)
# - Usa `round()`

# %%
# Tu reto aquí:

# %% [markdown]
# ---
# ## 🔎 Solución
#
# <details>
# <summary>Ver solución</summary>
#
# ```python
# numeros = []
#
# for _ in range(3):
#     numeros.append(float(input("Número: ")))
#
# suma = sum(numeros)
# promedio = round(suma / len(numeros), 2)
#
# print("Suma:", suma)
# print("Máximo:", max(numeros))
# print("Mínimo:", min(numeros))
# print("Promedio:", promedio)
# ```
#
# </details>
