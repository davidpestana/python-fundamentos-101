# %% [markdown]
# # 🐍 Unidad 6 – Construcción de Funciones
# ## Bloque 1 – def, parámetros y return
#
# ---
#
# ## 🎯 Objetivos
#
# - Definir funciones con `def`.
# - Comprender parámetros y argumentos.
# - Usar `return` correctamente.
# - Diferenciar función que imprime vs función que devuelve.

# %% [markdown]
# ## 🧠 Definir una función
#
# ```python
# def nombre_funcion():
#     bloque
# ```

# %%
def saludar():
    print("Hola")

saludar()
# Out:
# Hola

# %% [markdown]
# ## 🔢 Parámetros

# %%
def saludar(nombre):
    print("Hola", nombre)

saludar("Ana")
# Out:
# Hola Ana

# %% [markdown]
# ## 🔁 return
#
# Devuelve un valor.

# %%
def sumar(a, b):
    return a + b

resultado = sumar(3, 5)
print(resultado)
# Out:
# 8

# %% [markdown]
# ## ⚠️ print vs return
#
# - `print()` muestra.
# - `return` entrega valor.

# %% [markdown]
# ## 🧠 Ejercicio 1 — Función doble
#
# Crea una función que reciba un número y devuelva el doble.
#
# ### ✅ Pista
#
# - `return numero * 2`

# %%
# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 2 — Función saludo completo
#
# Crea una función que reciba nombre y edad y devuelva una frase.
#
# ### ✅ Pista
#
# - Usa f-string
# - Devuelve la frase

# %%
# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 3 — Función calculadora
#
# Crea una función que reciba dos números y devuelva:
#
# - Suma
# - Resta
#
# Devuelve ambos valores.
#
# ### ✅ Pista
#
# - Puedes devolver múltiples valores: `return a, b`

# %%
# Tu solución aquí:

# %% [markdown]
# ---
# ## 🏆 Reto Final — Validador
#
# Crea una función que:
#
# - Reciba un número.
# - Devuelva True si es par.
# - Devuelva False si es impar.
#
# Luego úsala dentro de un programa.
#
# ### ✅ Pista
#
# - Usa `% 2 == 0`

# %%
# Tu reto aquí:

# %% [markdown]
# ---
# ## 🔎 Solución
#
# <details>
# <summary>Ver solución</summary>
#
# ```python
# def es_par(numero):
#     return numero % 2 == 0
#
# print(es_par(4))
# print(es_par(7))
# ```
#
# </details>
