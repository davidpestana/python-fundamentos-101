# %% [markdown]
# # 🐍 Unidad 11 – Entornos Virtuales y Gestión de Dependencias
# ## Bloque 1 – venv, pip y estructura de proyecto
#
# ---
#
# ## 🎯 Objetivos
#
# - Entender por qué usar entornos virtuales.
# - Crear y activar un entorno con venv.
# - Instalar paquetes con pip.
# - Generar requirements.txt.
# - Comprender estructura básica de proyecto Python.

# %% [markdown]
# ## 🤔 ¿Por qué entornos virtuales?
#
# - Aislan dependencias por proyecto.
# - Evitan conflictos de versiones.
# - Permiten reproducibilidad.

# %% [markdown]
# ## 🛠 Crear entorno virtual
#
# Desde terminal (NO en notebook):
#
# ```bash
# python -m venv .venv
# source .venv/bin/activate
# ```

# %% [markdown]
# ## 📦 Instalar paquetes
#
# ```bash
# pip install requests
# ```

# %% [markdown]
# ## 🧾 Generar requirements.txt
#
# ```bash
# pip freeze > requirements.txt
# ```

# %% [markdown]
# ## 🏗 Estructura básica de proyecto
#
# ```
# mi_proyecto/
# │
# ├── src/
# │   ├── __init__.py
# │   └── main.py
# │
# ├── tests/
# ├── requirements.txt
# └── README.md
# ```

# %% [markdown]
# ## 🧠 Ejercicio 1 — Crear entorno
#
# En tu proyecto actual:
#
# 1. Crea entorno virtual.
# 2. Actívalo.
# 3. Instala paquete `requests`.
#
# ### ✅ Pistas
#
# - python -m venv .venv
# - source .venv/bin/activate
# - pip install requests

# %% [markdown]
# ## 🧠 Ejercicio 2 — requirements
#
# Genera archivo requirements.txt.
#
# Luego crea entorno nuevo y reinstala dependencias.
#
# ### ✅ Pista
#
# - pip install -r requirements.txt

# %% [markdown]
# ## 🧠 Ejercicio 3 — Mini estructura
#
# Crea estructura:
#
# - carpeta src
# - archivo main.py
# - archivo __init__.py
#
# Dentro de main.py escribe un print.

# %% [markdown]
# ---
# ## 🏆 Reto Final — Proyecto limpio
#
# 1. Crea proyecto llamado "demo_app".
# 2. Crea entorno virtual.
# 3. Instala requests y pandas.
# 4. Genera requirements.txt.
# 5. Crea carpeta src con main.py.
# 6. Ejecuta main.py.
#
# ### ✅ Pistas
#
# - Organiza bien carpetas.
# - No subas .venv al repositorio.

# %% [markdown]
# ---
# ## 🔎 Solución (pasos terminal)
#
# <details>
# <summary>Ver pasos</summary>
#
# ```bash
# mkdir demo_app
# cd demo_app
# python -m venv .venv
# source .venv/bin/activate
# pip install requests pandas
# pip freeze > requirements.txt
# mkdir src
# touch src/__init__.py
# echo 'print("App funcionando")' > src/main.py
# python src/main.py
# ```
#
# </details>
