# %% [markdown]
# # 🐍 Unidad 11 – Entornos Virtuales y Gestión de Dependencias
# ## Bloque 2 – Poetry y Pipenv (alternativas modernas)
#
# ---
#
# ## 🎯 Objetivos
#
# - Entender limitaciones de venv + pip.
# - Conocer Poetry.
# - Conocer Pipenv.
# - Comparar herramientas modernas.

# %% [markdown]
# ## 🤔 ¿Por qué alternativas?
#
# Problemas clásicos:
#
# - requirements.txt no distingue dependencias dev.
# - No gestiona versión de Python fácilmente.
# - No genera lock robusto por defecto.

# %% [markdown]
# ## 📦 Poetry
#
# ### Instalación (fuera del notebook)
#
# ```bash
# pip install poetry
# ```
#
# ### Crear proyecto
#
# ```bash
# poetry new mi_proyecto
# cd mi_proyecto
# ```

# %% [markdown]
# ### Añadir dependencias
#
# ```bash
# poetry add requests
# poetry add --group dev pytest
# ```

# %% [markdown]
# ## 📦 Pipenv
#
# ### Instalación
#
# ```bash
# pip install pipenv
# ```
#
# ### Crear entorno
#
# ```bash
# pipenv install requests
# ```

# %% [markdown]
# ## 🔍 Comparativa rápida
#
# | Herramienta | Lock file | Dev deps | pyproject.toml |
# |-------------|-----------|----------|----------------|
# | pip         | ❌        | ❌       | ❌             |
# | Pipenv      | ✅        | ✅       | ❌             |
# | Poetry      | ✅        | ✅       | ✅             |

# %% [markdown]
# ## 🧠 Ejercicio 1 — Proyecto Poetry
#
# 1. Crea proyecto con Poetry.
# 2. Añade requests.
# 3. Ejecuta shell poetry.
#
# ### ✅ Pistas
#
# - poetry new nombre
# - poetry shell

# %% [markdown]
# ## 🧠 Ejercicio 2 — Comparar lock
#
# Abre:
#
# - poetry.lock
# - Pipfile.lock
#
# ¿Qué diferencias observas?

# %% [markdown]
# ---
# ## 🏆 Reto Final
#
# Crea pequeño proyecto con Poetry que:
#
# 1. Tenga requests y pandas.
# 2. Añada pytest como dev dependency.
# 3. Ejecute script simple desde src.
#
# ### ✅ Pistas
#
# - poetry add pandas
# - poetry add --group dev pytest

# %% [markdown]
# ---
# ## 🔎 Solución (comandos)
#
# <details>
# <summary>Ver pasos</summary>
#
# ```bash
# poetry new demo_poetry
# cd demo_poetry
# poetry add requests pandas
# poetry add --group dev pytest
# poetry shell
# ```
#
# </details>
