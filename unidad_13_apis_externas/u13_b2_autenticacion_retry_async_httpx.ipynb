# %% [markdown]
# # 🐍 Unidad 13 – Llamadas a APIs Externas
# ## Bloque 2 – Autenticación, reintentos y cliente async con httpx
#
# ---
#
# ## 🎯 Objetivos
#
# - Enviar headers personalizados (API Key / Bearer).
# - Implementar estrategia básica de reintentos.
# - Introducir httpx para peticiones async.
# - Comparar requests vs httpx.

# %% [markdown]
# ⚠️ Instala httpx si no lo tienes:
#
# ```bash
# pip install httpx
# ```

# %% [markdown]
# ## 🔐 Enviar API Key en headers

# %%
import requests

headers = {
    "Authorization": "Bearer MI_TOKEN_FAKE",
    "X-API-KEY": "123456"
}

response = requests.get(
    "https://jsonplaceholder.typicode.com/posts/1",
    headers=headers
)

print(response.status_code)

# %% [markdown]
# ## 🔁 Reintentos básicos manuales

# %%
import time

def get_con_retry(url, intentos=3):
    for intento in range(intentos):
        response = requests.get(url)
        if response.status_code == 200:
            return response.json()
        print(f"Intento {intento + 1} fallido")
        time.sleep(1)
    raise Exception("No se pudo completar la petición")

print(get_con_retry("https://jsonplaceholder.typicode.com/posts/1"))

# %% [markdown]
# ## ⚡ Cliente async con httpx

# %%
import httpx
import asyncio

async def fetch_post(post_id):
    async with httpx.AsyncClient() as client:
        response = await client.get(
            f"https://jsonplaceholder.typicode.com/posts/{post_id}"
        )
        return response.json()

print(asyncio.run(fetch_post(1)))

# %% [markdown]
# ## 🔄 Múltiples requests async

# %%
async def main():
    async with httpx.AsyncClient() as client:
        tasks = [
            client.get(f"https://jsonplaceholder.typicode.com/posts/{i}")
            for i in range(1, 6)
        ]
        responses = await asyncio.gather(*tasks)
        return [r.json()["title"] for r in responses]

print(asyncio.run(main()))

# %% [markdown]
# ## 🧠 Ejercicio 1 — Retry con validación
#
# Modifica get_con_retry para que solo reintente si status != 200.
#
# ### ✅ Pista
#
# - Valida status_code antes de return

# %%
# Tu solución aquí:

# %% [markdown]
# ## 🧠 Ejercicio 2 — Async múltiples usuarios
#
# Crea función async que reciba lista de IDs.
# Devuelva lista de títulos.
#
# ### ✅ Pista
#
# - Usa gather()
# - Devuelve lista final

# %%
# Tu solución aquí:

# %% [markdown]
# ---
# ## 🏆 Reto Final — Cliente API robusto
#
# Crea clase `APIClient` que:
#
# - Reciba base_url.
# - Tenga método get(endpoint).
# - Maneje headers.
# - Implemente retry.
#
# Opcional: versión async.
#
# ### ✅ Pistas
#
# - Guarda base_url en __init__.
# - Usa requests.get().
# - Implementa bucle de reintento.

# %%
# Tu reto aquí:

# %% [markdown]
# ---
# ## 🔎 Solución
#
# <details>
# <summary>Ver solución</summary>
#
# ```python
# class APIClient:
#     def __init__(self, base_url, headers=None):
#         self.base_url = base_url
#         self.headers = headers or {}
#
#     def get(self, endpoint, intentos=3):
#         import time
#         import requests
#
#         url = f"{self.base_url}/{endpoint}"
#
#         for _ in range(intentos):
#             response = requests.get(url, headers=self.headers)
#             if response.status_code == 200:
#                 return response.json()
#             time.sleep(1)
#
#         raise Exception("Error tras varios intentos")
#
# client = APIClient("https://jsonplaceholder.typicode.com")
# print(client.get("posts/1"))
# ```
#
# </details>
